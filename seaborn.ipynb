# %% [markdown]
# <a href="https://colab.research.google.com/github/pearl24680/python-practice/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sea born used for data visualisation and based on matllotlib .it allow the creation of statistical graphics ..support multi-plot graph.

# %%
# !pip install seaborn

# %% [markdown]
# installing dependencie ..... 1 numpy 2 scipy 3 matplotlib 4 pandas  stats models statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
a = sns.load_dataset("flights")
sns.relplot(x="passengers",y="month",data=a)

# %%
a = sns.load_dataset("flights")
sns.relplot(x="passengers",y="month",hue="year",data=a)

# %%
b= sns.load_dataset("tips")
sns.relplot(x="total_bill",y="tip",hue="smoker",style="time",data=b)

# %% [markdown]
# seaborn functions
# statistical realtionship
# categorical data
# visualizing the distributing of a dataset

# %%
sns.catplot(x="day",y="total_bill",kind="swarm",data=b)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.catplot(x="day",y="total_bill",kind="violin",data=b)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.catplot(x="day",y="total_bill",kind="boxen",data=b)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
from scipy import stats

# %% [markdown]
# univarient distribution

# %%
# !pip install scipy
import numpy as np
from scipy import stats
# use the np.random.normal function to create random numbers from a normal distribution.
c = np.random.normal(loc=5,size=100,scale=2)
sns.distplot(c)
# Out:
# ...
# <ipython-input-22-5c6ae2a97b2a>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c)
# <Axes: ylabel='Density'>
